# %% [markdown]
# <a href="https://colab.research.google.com/github/YusufPutraBintangSatria/Natural_Language_Processing/blob/main/wordtokenization_TugasP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NLP
import re
import string

# Teks yang akan diproses
text = """Universitas Pelita Bangsa, yang terletak di Cikarang, Bekasi, adalah salah satu universitas swasta yang terus berkembang pesat di Indonesia! Kampus ini menawarkan berbagai program studi, mulai dari Teknik Informatika, Manajemen, hingga Ilmu Hukum, yang semuanya dirancang untuk membekali mahasiswa dengan keterampilan yang relevan di dunia kerja. Dengan lokasi strategis di kawasan industri (apakah ini bukan keuntungan besar?), Universitas Pelita Bangsa memiliki banyak keunggulan, termasuk akses mudah ke berbagai perusahaan besar untuk keperluan magang dan kerja sama industri! Visi kampus ini adalah mencetak lulusan yang berdaya saing tinggi melalui pengajaran yang berkualitas dan fasilitas modern (wow!), yang didukung oleh dosen-dosen berpengalaman."""

# Fungsi untuk membersihkan dan memproses teks
def tokenize_text(text):
    # Ubah teks menjadi huruf kecil
    text = text.lower()
    # Hapus tanda baca
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Pisahkan teks menjadi kata-kata
    words = text.split()
    return words

# Proses teks dan ambil hasilnya
tokens = tokenize_text(text)

# Tampilkan hasil
print(f"Ada {len(tokens)} kata.")
for i, word in enumerate(tokens, 1):
    print(f"Kata {i}: {word}")
# Out:
# Ada 100 kata.
# Kata 1: universitas
# Kata 2: pelita
# Kata 3: bangsa
# Kata 4: yang
# Kata 5: terletak
# Kata 6: di
# Kata 7: cikarang
# Kata 8: bekasi
# Kata 9: adalah
# Kata 10: salah
# Kata 11: satu
# Kata 12: universitas
# Kata 13: swasta
# Kata 14: yang
# Kata 15: terus
# Kata 16: berkembang
# Kata 17: pesat
# Kata 18: di
# Kata 19: indonesia
# Kata 20: kampus
# Kata 21: ini
# Kata 22: menawarkan
# Kata 23: berbagai
# Kata 24: program
# Kata 25: studi
# Kata 26: mulai
# Kata 27: dari
# Kata 28: teknik
# Kata 29: informatika
# Kata 30: manajemen
# Kata 31: hingga
# Kata 32: ilmu
# Kata 33: hukum
# Kata 34: yang
# Kata 35: semuanya
# Kata 36: dirancang
# Kata 37: untuk
# Kata 38: membekali
# Kata 39: mahasiswa
# Kata 40: dengan
# Kata 41: keterampilan
# Kata 42: yang
# Kata 43: relevan
# Kata 44: di
# Kata 45: dunia
# Kata 46: kerja
# Kata 47: dengan
# Kata 48: lokasi
# Kata 49: strategis
# Kata 50: di
# Kata 51: kawasan
# Kata 52: industri
# Kata 53: apakah
# Kata 54: ini
# Kata 55: bukan
# Kata 56: keuntungan
# Kata 57: besar
# Kata 58: universitas
# Kata 59: pelita
# Kata 60: bangsa
# Kata 61: memiliki
# Kata 62: banyak
# Kata 63: keunggulan
# Kata 64: termasuk
# Kata 65: akses
# Kata 66: mudah
# Kata 67: ke
# Kata 68: berbagai
# Kata 69: perusahaan
# Kata 70: besar
# Kata 71: untuk
# Kata 72: keperluan
# Kata 73: magang
# Kata 74: dan
# Kata 75: kerja
# Kata 76: sama
# Kata 77: industri
# Kata 78: visi
# Kata 79: kampus
# Kata 80: ini
# Kata 81: adalah
# Kata 82: mencetak
# Kata 83: lulusan
# Kata 84: yang
# Kata 85: berdaya
# Kata 86: saing
# Kata 87: tinggi
# Kata 88: melalui
# Kata 89: pengajaran
# Kata 90: yang
# Kata 91: berkualitas
# Kata 92: dan
# Kata 93: fasilitas
# Kata 94: modern
# Kata 95: wow
# Kata 96: yang
# Kata 97: didukung
# Kata 98: oleh
# Kata 99: dosendosen
# Kata 100: berpengalaman

# %%
from IPython import get_ipython
from IPython.display import display
# %%
# NLP
import re
import string

# Teks yang akan diproses
text = """Universitas Pelita Bangsa, yang terletak di Cikarang, Bekasi, adalah salah satu universitas swasta yang terus berkembang pesat di Indonesia! Kampus ini menawarkan berbagai program studi, mulai dari Teknik Informatika, Manajemen, hingga Ilmu Hukum, yang semuanya dirancang untuk membekali mahasiswa dengan keterampilan yang relevan di dunia kerja. Dengan lokasi strategis di kawasan industri (apakah ini bukan keuntungan besar?), Universitas Pelita Bangsa memiliki banyak keunggulan, termasuk akses mudah ke berbagai perusahaan besar untuk keperluan magang dan kerja sama industri! Visi kampus ini adalah mencetak lulusan yang berdaya saing tinggi melalui pengajaran yang berkualitas dan fasilitas modern (wow!), yang didukung oleh dosen-dosen berpengalaman."""

# Fungsi untuk membersihkan dan memproses teks
def tokenize_text(text):
    # Ubah teks menjadi huruf kecil
    text = text.lower()
    # Hapus tanda baca
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Pisahkan teks menjadi kata-kata
    words = text.split()
    return words

# Proses teks dan ambil hasilnya
tokens = tokenize_text(text)


nama = "Yusuf Putra Bintang Satria"
nim = "312110317"
kelas = "TI.21.A.AI.1"
matkul = "Natural Language Processing"
dosen = "Muhammad Najamuddin Dwi Miharja, S.Kom, M.Kom."
tugas = "Pertemuan ke-1"

print(f"Tugas: {tugas}")
print(f"Nama: {nama}")
print(f"NIM: {nim}")
print(f"Kelas: {kelas}")
print(f"Matkul: {matkul}")
print(f"Dosen Pengampu: {dosen}")
print("\n") # Memberi baris baru untuk memisahkan informasi dan output tokenisasi
# --- Akhir Informasi Tambahan ---

# Tampilkan hasil
print(f"Ada {len(tokens)} kata.")
for i, word in enumerate(tokens, 1):
    print(f"Kata {i}: {word}")
# %%
# Out:
# Tugas: Pertemuan ke-1
# Nama: Yusuf Putra Bintang Satria
# NIM: 312110317
# Kelas: TI.21.A.AI.1
# Matkul: Natural Language Processing
# Dosen Pengampu: Muhammad Najamuddin Dwi Miharja, S.Kom, M.Kom.
#
#
# Ada 100 kata.
# Kata 1: universitas
# Kata 2: pelita
# Kata 3: bangsa
# Kata 4: yang
# Kata 5: terletak
# Kata 6: di
# Kata 7: cikarang
# Kata 8: bekasi
# Kata 9: adalah
# Kata 10: salah
# Kata 11: satu
# Kata 12: universitas
# Kata 13: swasta
# Kata 14: yang
# Kata 15: terus
# Kata 16: berkembang
# Kata 17: pesat
# Kata 18: di
# Kata 19: indonesia
# Kata 20: kampus
# Kata 21: ini
# Kata 22: menawarkan
# Kata 23: berbagai
# Kata 24: program
# Kata 25: studi
# Kata 26: mulai
# Kata 27: dari
# Kata 28: teknik
# Kata 29: informatika
# Kata 30: manajemen
# Kata 31: hingga
# Kata 32: ilmu
# Kata 33: hukum
# Kata 34: yang
# Kata 35: semuanya
# Kata 36: dirancang
# Kata 37: untuk
# Kata 38: membekali
# Kata 39: mahasiswa
# Kata 40: dengan
# Kata 41: keterampilan
# Kata 42: yang
# Kata 43: relevan
# Kata 44: di
# Kata 45: dunia
# Kata 46: kerja
# Kata 47: dengan
# Kata 48: lokasi
# Kata 49: strategis
# Kata 50: di
# Kata 51: kawasan
# Kata 52: industri
# Kata 53: apakah
# Kata 54: ini
# Kata 55: bukan
# Kata 56: keuntungan
# Kata 57: besar
# Kata 58: universitas
# Kata 59: pelita
# Kata 60: bangsa
# Kata 61: memiliki
# Kata 62: banyak
# Kata 63: keunggulan
# Kata 64: termasuk
# Kata 65: akses
# Kata 66: mudah
# Kata 67: ke
# Kata 68: berbagai
# Kata 69: perusahaan
# Kata 70: besar
# Kata 71: untuk
# Kata 72: keperluan
# Kata 73: magang
# Kata 74: dan
# Kata 75: kerja
# Kata 76: sama
# Kata 77: industri
# Kata 78: visi
# Kata 79: kampus
# Kata 80: ini
# Kata 81: adalah
# Kata 82: mencetak
# Kata 83: lulusan
# Kata 84: yang
# Kata 85: berdaya
# Kata 86: saing
# Kata 87: tinggi
# Kata 88: melalui
# Kata 89: pengajaran
# Kata 90: yang
# Kata 91: berkualitas
# Kata 92: dan
# Kata 93: fasilitas
# Kata 94: modern
# Kata 95: wow
# Kata 96: yang
# Kata 97: didukung
# Kata 98: oleh
# Kata 99: dosendosen
# Kata 100: berpengalaman
