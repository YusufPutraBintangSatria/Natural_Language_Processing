# %% [markdown]
# <a href="https://colab.research.google.com/github/YusufPutraBintangSatria/ElectronicCodeBook/blob/main/wordtokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library yang dibutuhkan
import nltk
from nltk.tokenize import word_tokenize

# Pastikan nltk memiliki resource yang dibutuhkan
nltk.download('punkt')

# Teks yang akan di-tokenisasi
teks = """
Universitas Pelita Bangsa, yang terletak di Cikarang, Bekasi, adalah salah satu universitas swasta yang terus berkembang pesat di Indonesia!
Kampus ini menawarkan berbagai program studi, mulai dari Teknik Informatika, Manajemen, hingga Ilmu Hukum,
yang semuanya dirancang untuk membekali mahasiswa dengan keterampilan yang relevan di dunia kerja.
Dengan lokasi strategis di kawasan industri (apakah ini bukan keuntungan besar?), Universitas Pelita Bangsa
memiliki banyak keunggulan, termasuk akses mudah ke berbagai perusahaan besar untuk keperluan magang dan kerja sama industri!
Visi kampus ini adalah mencetak lulusan yang berdaya saing tinggi melalui pengajaran yang berkualitas dan fasilitas modern (wow!),
yang didukung oleh dosen-dosen berpengalaman.
"""

# Lakukan word tokenization
tokens = word_tokenize(teks)

# Hapus tanda baca dari hasil tokenisasi
tokens_no_punctuation = [word for word in tokens if word.isalpha()]

# Tampilkan kata-kata secara berurutan
for i, word in enumerate(tokens_no_punctuation, 1):
    print(f"{i}. {word.lower()}")
# Out:
# 1. universitas
# 2. pelita
# 3. bangsa
# 4. yang
# 5. terletak
# 6. di
# 7. cikarang
# 8. bekasi
# 9. adalah
# 10. salah
# 11. satu
# 12. universitas
# 13. swasta
# 14. yang
# 15. terus
# 16. berkembang
# 17. pesat
# 18. di
# 19. indonesia
# 20. kampus
# 21. ini
# 22. menawarkan
# 23. berbagai
# 24. program
# 25. studi
# 26. mulai
# 27. dari
# 28. teknik
# 29. informatika
# 30. manajemen
# 31. hingga
# 32. ilmu
# 33. hukum
# 34. yang
# 35. semuanya
# 36. dirancang
# 37. untuk
# 38. membekali
# 39. mahasiswa
# 40. dengan
# 41. keterampilan
# 42. yang
# 43. relevan
# 44. di
# 45. dunia
# 46. kerja
# 47. dengan
# 48. lokasi
# 49. strategis
# 50. di
# 51. kawasan
# 52. industri
# 53. apakah
# 54. ini
# 55. bukan
# 56. keuntungan
# 57. besar
# 58. universitas
# 59. pelita
# 60. bangsa
# 61. memiliki
# 62. banyak
# 63. keunggulan
# 64. termasuk
# 65. akses
# 66. mudah
# 67. ke
# 68. berbagai
# 69. perusahaan
# 70. besar
# 71. untuk
# 72. keperluan
# 73. magang
# 74. dan
# 75. kerja
# ...
